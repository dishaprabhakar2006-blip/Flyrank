# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dishaprabhakar2006-blip/Flyrank/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
# Task type: Scoring / Ranking. I'm not sorting pages into fixed categories (classification) or grouping similar pages (clustering) — I'm producing a ranked priority score per page, so a reviewer knows which page to look at first. It's technically built on top of a binary classifier's probability output (declining vs not), but the actual product is a ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# Proxy target: is_declining_label = (trend_direction == "down"), same as the starter pipeline. This is explicitly called out in the guide as a proxy, not the ideal — it's a current-window bucket, not a future outcome.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# Precision@50 — of the top 50 pages my ranking flags, how many are genuinely declining? This matches how the output would actually be used: a reviewer only has capacity to check a limited number of pages, so ranking quality at the top matters more than overall accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df[["content_id", "client_id", "impressions_90d", "avg_position", "ctr", "trend_direction"]].head()

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A hand-written rule (like "stale + visible" from notebook 02) can only combine a small number of signals a human thought to check, in a fixed way. A learned model can find non-obvious combinations across many signals (impressions, position, CTR, freshness, word count, etc.) that predict decline better than any single rule — which is exactly what we saw: the random forest hit Precision@50 = 0.740 vs the baseline rule's 0.240, roughly 3x better. That gap is direct evidence this is a genuine ML problem, not just a fixed-rule problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
